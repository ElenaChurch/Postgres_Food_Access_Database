# %%
#importing stuff
import pandas as pd

# %%
heartdiseasefilepath='resources/Heart Disease Mortality.csv'

# %%
heartdisease_df=pd.read_csv(heartdiseasefilepath)
heartdisease_df
# Out:
#        Year LocationAbbr    LocationDesc GeographicLevel DataSource  \
# 0      2017           AK  Aleutians East          County       NVSS
# 1      2017           AK  Aleutians West          County       NVSS
# 2      2017           AK       Anchorage          County       NVSS
# 3      2017           AK          Bethel          County       NVSS
# 4      2017           AK     Bristol Bay          County       NVSS
# ...     ...          ...             ...             ...        ...
# 59089  2017           WY         Wyoming           State       NVSS
# 59090  2017           WY         Wyoming           State       NVSS
# 59091  2017           WY         Wyoming           State       NVSS
# 59092  2017           WY         Wyoming           State       NVSS
# 59093  2017           WY         Wyoming           State       NVSS
#
#                          Class                    Topic  Data_Value  \
# 0      Cardiovascular Diseases  Heart Disease Mortality       172.9
# ...

# %%
heartdisease_df=heartdisease_df[['Year','LocationAbbr','LocationDesc','GeographicLevel', 'Data_Value',
'Data_Value_Unit',
'Stratification1',
'Stratification2',
'LocationID'
]]
heartdisease_df
# Out:
#        Year LocationAbbr    LocationDesc GeographicLevel  Data_Value  \
# 0      2017           AK  Aleutians East          County       172.9
# 1      2017           AK  Aleutians West          County       172.2
# 2      2017           AK       Anchorage          County       243.3
# 3      2017           AK          Bethel          County       337.1
# 4      2017           AK     Bristol Bay          County         NaN
# ...     ...          ...             ...             ...         ...
# 59089  2017           WY         Wyoming           State         NaN
# 59090  2017           WY         Wyoming           State         NaN
# 59091  2017           WY         Wyoming           State       313.1
# 59092  2017           WY         Wyoming           State       328.0
# 59093  2017           WY         Wyoming           State       291.3
#
#               Data_Value_Unit Stratification1  \
# 0      per 100,000 population         Overall
# ...

# %%
overall_1 = heartdisease_df['Stratification1']=="Overall"
overall_2 = heartdisease_df['Stratification2']=="Overall"
county = heartdisease_df['GeographicLevel']=="County"

strat1 = heartdisease_df[overall_1]
strat2 = strat1[overall_2]
hd_df = strat2[county]
hd_df
# Out:
# /var/folders/y2/65gh7zxx3mbdxlrh871gqx580000gn/T/ipykernel_48365/926266581.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   strat2 = strat1[overall_2]
# /var/folders/y2/65gh7zxx3mbdxlrh871gqx580000gn/T/ipykernel_48365/926266581.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   hd_df = strat2[county]
#        Year LocationAbbr       LocationDesc GeographicLevel  Data_Value  \
# 0      2017           AK     Aleutians East          County       172.9
# 1      2017           AK     Aleutians West          County       172.2
# 2      2017           AK          Anchorage          County       243.3
# 3      2017           AK             Bethel          County       337.1
# 4      2017           AK        Bristol Bay          County         NaN
# ...     ...          ...                ...             ...         ...
# 58681  2017           WY  Sweetwater County          County       352.6
# ...

# %%
#finding count of NAN
hd_df.isna().sum()
#droping NAN
hd_df=hd_df.dropna()
#checking that it worked
hd_df.isna().sum()
# Out:
# Year               0
# LocationAbbr       0
# LocationDesc       0
# GeographicLevel    0
# Data_Value         0
# Data_Value_Unit    0
# Stratification1    0
# Stratification2    0
# LocationID         0
# dtype: int64

# %%
hd_df=hd_df.rename(columns={'Year': 'Year',
'LocationAbbr':'State',
'LocationDesc':'County',
'GeographicLevel':'Location Type',
'Data_Value':'Heart Disease Mortality Rate',
'Data_Value_Unit':'Value Unit',
'Stratification1':'Stratification 1',
'Stratification2':'Stratification 2',
'LocationID':'Location ID'})
hd_df
# Out:
#        Year State             County Location Type  \
# 0      2017    AK     Aleutians East        County
# 1      2017    AK     Aleutians West        County
# 2      2017    AK          Anchorage        County
# 3      2017    AK             Bethel        County
# 5      2017    AK             Denali        County
# ...     ...   ...                ...           ...
# 58681  2017    WY  Sweetwater County        County
# 58682  2017    WY       Teton County        County
# 58683  2017    WY       Uinta County        County
# 58684  2017    WY    Washakie County        County
# 58685  2017    WY      Weston County        County
#
#        Heart Disease Mortality Rate              Value Unit Stratification 1  \
# 0                             172.9  per 100,000 population          Overall
# 1                             172.2  per 100,000 population          Overall
# 2                             243.3  per 100,000 population          Overall
# ...

# %%
clean_hd = hd_df[['State','County', 'Heart Disease Mortality Rate',
'Value Unit',
'Location ID'
]]
clean_hd
# Out:
#       State             County  Heart Disease Mortality Rate  \
# 0        AK     Aleutians East                         172.9
# 1        AK     Aleutians West                         172.2
# 2        AK          Anchorage                         243.3
# 3        AK             Bethel                         337.1
# 5        AK             Denali                         240.9
# ...     ...                ...                           ...
# 58681    WY  Sweetwater County                         352.6
# 58682    WY       Teton County                         157.7
# 58683    WY       Uinta County                         333.9
# 58684    WY    Washakie County                         305.7
# 58685    WY      Weston County                         297.9
#
#                    Value Unit  Location ID
# 0      per 100,000 population         2013
# 1      per 100,000 population         2016
# 2      per 100,000 population         2020
# 3      per 100,000 population         2050
# ...
